# %%
import matplotlib.pyplot as plt #import library for plotting graphs

# %%
year = [2016,2017,2018,2019,2020]

# %%
plastic_bioplastic = [500,550,600,650,700]

# %%
plt.plot (year,plastic_bioplastic)
plt.title ('Plastic VS Bioplastic')
plt.xlabel ('year')
plt.ylabel ('plast_bioplastic')
plt.show()

# %%
import csv
with open("Project.csv","r") as csvfile:
  reader=csv.reader(csvfile)
for row in reader:
  print(row)
